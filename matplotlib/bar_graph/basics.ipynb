# %%
import matplotlib.pyplot
import numpy

x = numpy.arange(3)
years = ['2022', '2023', '2024']
values = [100, 400, 900]

matplotlib.pyplot.bar(x, values, color=['r','g','b'])
matplotlib.pyplot.xticks(x, years)

matplotlib.pyplot.show()
